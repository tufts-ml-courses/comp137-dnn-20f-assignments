# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform a regression task and a classification task. You need to implement two classes, `DenseLayer` and `Feedforward`, and the `train` function `in implementation.py`

# %%
# A bit of setup

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %% [markdown]
# ## 1. Implement the two classes and one function (10 points)
#
# In this step, you should implement the two classes and one function mentioned above. The autograder can check the correcness of your two classes, `DenseLayer` and `Feedforward`. Correct implementation of each of the two classes worths 5 points, so you will 10 points if you make both correct.
#
# The autograder cannot check the training function because this function takes too much time to run.

# %% [markdown]
# ## 2. A toy regression problem
#
# By this step, you should already have implemented all necessary classes and functions in `implementation.py`. In this task, we have a toy regression problem. Please the data below and think about this question: is overfitting a problem for this problem? **Please write your answer below** (This particular question has no points, but you may want to show your thought).

# %%
def target_func(x):
    y = np.sin(1 / x)
    return y

# initialize training and validation sets. 
x_train = np.power(np.random.random_sample([2000, 1]), 4) + 0.05
y_train = target_func(x_train)

x_val = np.power(np.random.random_sample([2000, 1]), 4) + 0.05
y_val = target_func(x_val)


# plot the function and data points
# Do you worry about overfitting problem?
sort_ind = np.argsort(x_train[:, 0])
plt.plot(x_train[sort_ind, 0], y_train[sort_ind, 0])
plt.plot(x_train[sort_ind, 0], y_train[sort_ind, 0], '.')

# %% [markdown]
# ### Train the model  (5 points)
#
# Now lets run your `train` function on this data. You will need to save your model to a file and submit it. We will test your saved model. You will earn
#  * 2 points if your validation MSE is smaller than 0.1
#  * 4 points if your validation MSE is smaller than 0.05
#  * 5 points if your validation MSE is smaller than 0.01

# %%
from implementation import train

model, history = train(x_train, y_train, x_val, y_val, depth=4, hidden_sizes=[8, 8, 8], 
                       reg_weight=0.000001, num_train_epochs=150, task_type='regression')
# Out:
# Epoch 1/150
# 63/63 [==============================] - 0s 3ms/step - loss: 0.4823 - accuracy: 0.0000e+00 - val_loss: 0.4542 - val_accuracy: 5.0000e-04
# Epoch 2/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4383 - accuracy: 0.0000e+00 - val_loss: 0.4561 - val_accuracy: 5.0000e-04
# Epoch 3/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4355 - accuracy: 0.0000e+00 - val_loss: 0.4345 - val_accuracy: 5.0000e-04
# Epoch 4/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4342 - accuracy: 0.0000e+00 - val_loss: 0.4357 - val_accuracy: 5.0000e-04
# Epoch 5/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4319 - accuracy: 0.0000e+00 - val_loss: 0.4333 - val_accuracy: 5.0000e-04
# Epoch 6/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4321 - accuracy: 0.0000e+00 - val_loss: 0.4394 - val_accuracy: 5.0000e-04
# Epoch 7/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4251 - accuracy: 0.0000e+00 - val_loss: 0.4256 - val_accuracy: 5.0000e-04
# Epoch 8/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4077 - accuracy: 0.0000e+00 - val_loss: 0.4011 - val_accuracy: 5.0000e-04
# Epoch 9/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.3578 - accuracy: 0.0000e+00 - val_loss: 0.3651 - val_accuracy: 5.0000e-04
# Epoch 10/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3228 - accuracy: 0.0000e+00 - val_loss: 0.3650 - val_accuracy: 5.0000e-04
# Epoch 11/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2961 - accuracy: 0.0000e+00 - val_loss: 0.3230 - val_accuracy: 5.0000e-04
# Epoch 12/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.0000e+00 - val_loss: 0.3058 - val_accuracy: 5.0000e-04
# Epoch 13/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2784 - accuracy: 0.0000e+00 - val_loss: 0.3138 - val_accuracy: 5.0000e-04
# Epoch 14/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2933 - accuracy: 0.0000e+00 - val_loss: 0.3107 - val_accuracy: 5.0000e-04
# Epoch 15/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2771 - accuracy: 0.0000e+00 - val_loss: 0.3047 - val_accuracy: 5.0000e-04
# Epoch 16/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2787 - accuracy: 0.0000e+00 - val_loss: 0.3169 - val_accuracy: 5.0000e-04
# Epoch 17/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2773 - accuracy: 0.0000e+00 - val_loss: 0.3026 - val_accuracy: 5.0000e-04
# Epoch 18/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2773 - accuracy: 0.0000e+00 - val_loss: 0.3011 - val_accuracy: 5.0000e-04
# Epoch 19/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2724 - accuracy: 0.0000e+00 - val_loss: 0.2992 - val_accuracy: 5.0000e-04
# Epoch 20/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2712 - accuracy: 0.0000e+00 - val_loss: 0.2998 - val_accuracy: 5.0000e-04
# Epoch 21/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2686 - accuracy: 0.0000e+00 - val_loss: 0.2944 - val_accuracy: 5.0000e-04
# Epoch 22/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2711 - accuracy: 0.0000e+00 - val_loss: 0.2991 - val_accuracy: 5.0000e-04
# Epoch 23/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2665 - accuracy: 0.0000e+00 - val_loss: 0.2958 - val_accuracy: 5.0000e-04
# Epoch 24/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2669 - accuracy: 0.0000e+00 - val_loss: 0.2975 - val_accuracy: 5.0000e-04
# Epoch 25/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2621 - accuracy: 0.0000e+00 - val_loss: 0.2847 - val_accuracy: 5.0000e-04
# Epoch 26/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2585 - accuracy: 0.0000e+00 - val_loss: 0.2858 - val_accuracy: 5.0000e-04
# Epoch 27/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2571 - accuracy: 0.0000e+00 - val_loss: 0.2857 - val_accuracy: 5.0000e-04
# Epoch 28/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2544 - accuracy: 0.0000e+00 - val_loss: 0.2797 - val_accuracy: 5.0000e-04
# Epoch 29/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2529 - accuracy: 0.0000e+00 - val_loss: 0.2781 - val_accuracy: 5.0000e-04
# Epoch 30/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2535 - accuracy: 0.0000e+00 - val_loss: 0.2788 - val_accuracy: 5.0000e-04
# Epoch 31/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2531 - accuracy: 0.0000e+00 - val_loss: 0.2849 - val_accuracy: 5.0000e-04
# Epoch 32/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2506 - accuracy: 0.0000e+00 - val_loss: 0.2805 - val_accuracy: 5.0000e-04
# Epoch 33/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2504 - accuracy: 0.0000e+00 - val_loss: 0.2778 - val_accuracy: 5.0000e-04
# Epoch 34/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.0000e+00 - val_loss: 0.2740 - val_accuracy: 5.0000e-04
# Epoch 35/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2496 - accuracy: 0.0000e+00 - val_loss: 0.2732 - val_accuracy: 5.0000e-04
# Epoch 36/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.0000e+00 - val_loss: 0.2751 - val_accuracy: 5.0000e-04
# Epoch 37/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2486 - accuracy: 0.0000e+00 - val_loss: 0.2954 - val_accuracy: 5.0000e-04
# Epoch 38/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2557 - accuracy: 0.0000e+00 - val_loss: 0.2757 - val_accuracy: 5.0000e-04
# Epoch 39/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2512 - accuracy: 0.0000e+00 - val_loss: 0.2758 - val_accuracy: 5.0000e-04
# Epoch 40/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2484 - accuracy: 0.0000e+00 - val_loss: 0.2732 - val_accuracy: 5.0000e-04
# Epoch 41/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.0000e+00 - val_loss: 0.2755 - val_accuracy: 5.0000e-04
# Epoch 42/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2512 - accuracy: 0.0000e+00 - val_loss: 0.2722 - val_accuracy: 5.0000e-04
# Epoch 43/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2470 - accuracy: 0.0000e+00 - val_loss: 0.2753 - val_accuracy: 5.0000e-04
# Epoch 44/150
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2462 - accuracy: 0.0000e+00 - val_loss: 0.2690 - val_accuracy: 5.0000e-04
# Epoch 45/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2474 - accuracy: 0.0000e+00 - val_loss: 0.2762 - val_accuracy: 5.0000e-04
# Epoch 46/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2434 - accuracy: 0.0000e+00 - val_loss: 0.2638 - val_accuracy: 5.0000e-04
# Epoch 47/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2360 - accuracy: 0.0000e+00 - val_loss: 0.2447 - val_accuracy: 5.0000e-04
# Epoch 48/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2278 - accuracy: 0.0000e+00 - val_loss: 0.2238 - val_accuracy: 5.0000e-04
# Epoch 49/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2122 - accuracy: 0.0000e+00 - val_loss: 0.2335 - val_accuracy: 5.0000e-04
# Epoch 50/150
# 63/63 [==============================] - 0s 1ms/step - loss: 0
[==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 6.6749e-04 - val_accuracy: 5.0000e-04
# Epoch 149/150
# 63/63 [==============================] - 0s 2ms/step - loss: 8.5017e-04 - accuracy: 0.0000e+00 - val_loss: 7.0808e-04 - val_accuracy: 5.0000e-04
# Epoch 150/150
# 63/63 [==============================] - 0s 1ms/step - loss: 7.7170e-04 - accuracy: 0.0000e+00 - val_loss: 0.0014 - val_accuracy: 5.0000e-04

# %% [markdown]
# ### Plot training trace and the fitted model

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(1, 1, 1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title('Objective history')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
y_pred = model.predict(x_val)

plt.plot(x_val[:, 0], y_pred[:, 0], '.')
# Out:
# INFO:tensorflow:Assets written to: sin_inv_x.kmod/assets

# %% [markdown]
# ### Save the model
#
# Please save your model as follows. Make sure the saved model can be loaded correctly with `tf.keras.models.load_model('sin_inv_x.kmod')`. *If your model cannot be loaded, you will get zero points for this problem.*

# %%
model.save('sin_inv_x.kmod')
# Out:
# INFO:tensorflow:Assets written to: sin_inv_x.kmod/assets

# %% [markdown]
# ## 3. Classifying hand-written digits
#
# This task is a classification problem on the famous MNIST dataset.
#
# ### Load the data

# %%
from sklearn.model_selection import train_test_split

# load the dataset
data_train, data_test = tf.keras.datasets.mnist.load_data()

# separate a validation set
x_train, y_train = data_train 
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, train_size=0.8, stratify=y_train)

x_test, y_test = data_test

# treating images as vectors and create one hot representations of labesl

x_train = x_train.reshape([-1, 28 * 28])
x_val = x_val.reshape([-1, 28 * 28])
x_test = x_test.reshape([-1, 28 * 28])

y_train = tf.one_hot(y_train, depth=10).numpy()
y_val = tf.one_hot(y_val, depth=10).numpy()
y_test = tf.one_hot(y_test, depth=10).numpy()


print('Shape of training input: ', x_train.shape)
print('Shape of training labels: ', y_train.shape)
print('Shape of validation input: ', x_val.shape)
print('Shape of validation labels: ', y_val.shape)
print('Shape of test input: ', x_test.shape)
print('Shape of test labels: ', y_test.shape)
# Out:
# Shape of training input:  (48000, 784)
# Shape of training labels:  (48000, 10)
# Shape of validation input:  (12000, 784)
# Shape of validation labels:  (12000, 10)
# Shape of test input:  (10000, 784)
# Shape of test labels:  (10000, 10)

# %% [markdown]
# ### Train a model

# %%
from implementation import train

model, history = train(x_train, y_train, x_val, y_val, depth=3, hidden_sizes=[8, 8], reg_weight=0.01, num_train_epochs=40,  task_type='classification')
# Out:
# Epoch 1/40
# 1500/1500 [==============================] - 2s 1ms/step - loss: 50.2250 - accuracy: 0.4632 - val_loss: 37.4061 - val_accuracy: 0.6198
# Epoch 2/40
# 1500/1500 [==============================] - 1s 927us/step - loss: 34.3263 - accuracy: 0.6513 - val_loss: 36.0277 - val_accuracy: 0.6233
# Epoch 3/40
# 1500/1500 [==============================] - 1s 890us/step - loss: 31.2121 - accuracy: 0.6889 - val_loss: 29.7142 - val_accuracy: 0.7123
# Epoch 4/40
# 1500/1500 [==============================] - 1s 911us/step - loss: 29.4761 - accuracy: 0.7214 - val_loss: 27.8001 - val_accuracy: 0.7504
# Epoch 5/40
# 1500/1500 [==============================] - 1s 917us/step - loss: 27.6896 - accuracy: 0.7407 - val_loss: 27.8064 - val_accuracy: 0.7362
# Epoch 6/40
# 1500/1500 [==============================] - 1s 902us/step - loss: 26.3356 - accuracy: 0.7508 - val_loss: 26.0511 - val_accuracy: 0.7700
# Epoch 7/40
# 1500/1500 [==============================] - 1s 889us/step - loss: 25.8459 - accuracy: 0.7586 - val_loss: 25.3589 - val_accuracy: 0.7673
# Epoch 8/40
# 1500/1500 [==============================] - 1s 911us/step - loss: 23.9938 - accuracy: 0.7729 - val_loss: 25.3288 - val_accuracy: 0.7626
# Epoch 9/40
# 1500/1500 [==============================] - 1s 922us/step - loss: 24.2395 - accuracy: 0.7685 - val_loss: 23.8624 - val_accuracy: 0.7705
# Epoch 10/40
# 1500/1500 [==============================] - 2s 1ms/step - loss:
# Epoch 30/40
# 1500/1500 [==============================] - 1s 958us/step - loss: 21.2520 - accuracy: 0.8179 - val_loss: 21.8946 - val_accuracy: 0.8210
# Epoch 31/40
# 1500/1500 [==============================] - 1s 975us/step - loss: 21.3901 - accuracy: 0.8219 - val_loss: 22.6250 - val_accuracy: 0.8060
# Epoch 32/40
# 1500/1500 [==============================] - 1s 947us/step - loss: 20.6177 - accuracy: 0.8291 - val_loss: 21.0590 - val_accuracy: 0.8199
# Epoch 33/40
# 1500/1500 [==============================] - 1s 932us/step - loss: 20.2486 - accuracy: 0.8363 - val_loss: 19.6759 - val_accuracy: 0.8431
# Epoch 34/40
# 1500/1500 [==============================] - 1s 975us/step - loss: 20.2185 - accuracy: 0.8380 - val_loss: 21.9104 - val_accuracy: 0.8220
# Epoch 35/40
# 1500/1500 [==============================] - 1s 946us/step - loss: 19.7105 - accuracy: 0.8428 - val_loss: 19.4657 - val_accuracy: 0.8507
# Epoch 36/40
# 1500/1500 [==============================] - 1s 947us/step - loss: 18.8068 - accuracy: 0.8556 - val_loss: 18.8811 - val_accuracy: 0.8509
# Epoch 37/40
# 1500/1500 [==============================] - 2s 1ms/step - loss: 18.6516 - accuracy: 0.8579 - val_loss: 20.6775 - val_accuracy: 0.8267
# Epoch 38/40
# 1500/1500 [==============================] - 1s 950us/step - loss: 18.8862 - accuracy: 0.8510 - val_loss: 19.0702 - val_accuracy: 0.8587
# Epoch 39/40
# 1500/1500 [==============================] - 2s 1ms/step - loss: 19.2209 - accuracy: 0.8454 - val_loss: 20.4614 - val_accuracy: 0.8314
# Epoch 40/40
# 1500/1500 [==============================] - 1s 988us/step - loss: 19.1078 - accuracy: 0.8486 - val_loss: 18.6818 - val_accuracy: 0.8503

# %% [markdown]
# ### Debug the training (10 points)
#
# A neural network with your initial setting may not work straightforwardly, so you will need to diagnose the problems in the training procedure. One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks. This task gives you a chance to gain some experience. Below, you should experiment with different values of the various hyperparameters, including
#  * data preparation (data normalization and data augmentation)
#  * the achitecture (depth, hidden layer sizes, and activation functions),
#  * optimization (optimization algorithm, learning rate, learning rate decay, batch size, and numer of training epochs)
#  * regularization (regularization weight, dropout).
#
# **Expected results**. You goal in this exercise is to get as good of a result as you can, with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).  You should be aim to achieve a classification accuracy of greater than 80% on the test results.
#
# **Grading**. You will get
#   * 5 points if your model has an accuracy over 0.70
#   * 8 points if your model has an accuracy over 0.80
#   * 10 points if your model has an accuracy over 0.90

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title('Objective history')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %%
from vis_utils import visualize_grid

W1 = model.layers[0].W.numpy()
W1 = W1.transpose()
W1 = W1.reshape([W1.shape[0], 28, 28, 1])

plt.imshow(visualize_grid(W1))

# %% [markdown]
# Finally, test the model on the test set and show the accuracy.

# %%
y_pred = model.predict(x_test.astype(np.float32))

acc = np.mean(np.argmax(y_test, axis=1) == np.argmax(y_pred, axis=1))

print('The test accuracy is ', acc)
# Out:
# The test accuracy is  0.8595

# %% [markdown]
# ### Save the model

# %%
model.save('mnist_cls.kmod')
# Out:
# INFO:tensorflow:Assets written to: mnist_cls.kmod/assets

# %% [markdown]
# ## Question (5 points): what have you learned from this assignment?
#
# Please summarize your model tuning experience into three points below. If possible, please elaborate after your summarization.
#
# *Answer*:
